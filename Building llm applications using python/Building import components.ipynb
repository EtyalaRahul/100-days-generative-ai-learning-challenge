# %%
import os 
from dotenv import load_dotenv
load_dotenv()
os.environ['OPENAI_API_KEY']=os.getenv('OPENAI_API_KEY') 
#Langsmith tracking
os.environ['LANGCHAIN_API_KEY']=os.getenv('LANGCHAIN_API_KEY')
os.environ['LANGCHAIN_PROJECT']=os.getenv('LANGCHAIN_PROJECT')
os.environ['LANGCHAIN_TRACING_V2']="true"

# %%
from langchain_openai import ChatOpenAI 
llm=ChatOpenAI(model="gpt-4o",base_url=os.getenv("BASE_URL"))
print(llm)
# Out:
# metadata={'lc_versions': {'langchain-core': '1.4.9', 'langchain': '1.3.11', 'langchain-openai': '1.3.5'}} output_version=None profile={'name': 'GPT-4o', 'release_date': '2024-05-13', 'last_updated': '2024-08-06', 'open_weights': False, 'max_input_tokens': 128000, 'max_output_tokens': 16384, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'pdf_inputs': True, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True, 'tool_call_streaming': True} client=<openai.resources.chat.completions.completions.Completions object at 0x000001B176E8EB10> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000001B176E862A0> root_client=<openai.OpenAI object at 0x000001B174C47290> root_async_client=<openai.AsyncOpenAI object at 0x000001B176E8E2A0> model_name='gpt-4o' model_kwargs={} openai_api_key=SecretStr('**********') openai_api_base='https://api.aicredits.in/v1' openai_proxy=None stream_chunk_timeout=120.0

# %%
llm.invoke("who is krish naik").content
# Out:
# 'Krish Naik is a well-known data scientist and a prominent figure in the field of artificial intelligence and machine learning. He has made significant contributions through his educational content, primarily on YouTube, where he shares tutorials, courses, and insights on data science, machine learning, deep learning, and related technologies. Krish is also known for his work in educating and mentoring aspiring data scientists and tech enthusiasts, helping them to build and enhance their skills in the industry. He often shares practical examples, industry trends, and project-based learning to help learners gain hands-on experience.'

# %%
from langchain_core.prompts import ChatPromptTemplate 

prompt=ChatPromptTemplate.from_messages(
  [
    ("system","You are an expert AI Engineer. Provide me answers based on the questions"),
    ("user","{input}")
  ]
)

prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert AI Engineer. Provide me answers based on the questions'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
chain=prompt | llm

# %%
response=chain.invoke({
  "input" : "what is bjp?"
})

# %%
response
# Out:
# AIMessage(content='The BJP, or Bharatiya Janata Party, is one of the two major political parties in India, alongside the Indian National Congress. Established in 1980, the BJP has its ideological roots in Hindu nationalism and is associated with the broader political movement known as Hindutva. The party is known for its center-right political stance, advocating for conservative social policies, economic neoliberalism, and a strong national defense. The BJP has been a dominant force in Indian politics, having formed the government at the national level several times, with prominent leaders including Atal Bihari Vajpayee and Narendra Modi. The party is part of the National Democratic Alliance, a coalition of center-right parties in India.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 141, 'prompt_tokens': 30, 'total_tokens': 171, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}, 'cost': 0.17044044831198002, 'cost_details': {'completion_cost_inr': 0.16183234486188003, 'prompt_cost_inr': 0.008608103450100001}, 'latency_ms': 2323}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_94cd41efba', 'id': 'chatcmpl-E4lyxOodvJVcqjcoR1e4ddOVGKAJv', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f8ec0-aecc-7d13-970c-81492b873f63-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 30, 'output_tokens': 141, 'total_tokens': 171, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
### stroutput parser 
from langchain_core.output_parsers import StrOutputParser
output=StrOutputParser() 
chain=prompt | llm | output

# %%
chain.invoke({
  "input" : "what is rag?"
})
# Out:
# 'RAG is an acronym that can stand for different things depending on the context, but one prominent meaning in the field of AI and machine learning is **Retrieval-Augmented Generation**. RAG combines retrieval-based methods with generative models to improve the performance of language models, especially in tasks like question answering and open-domain dialogue.\n\n1. **Retrieval**: This component involves searching a large corpus or knowledge base to find relevant information or documents that might help in generating a more accurate or informed response. This is often achieved through techniques such as dense vector retrieval or other information retrieval methods.\n\n2. **Augmented Generation**: Once the relevant pieces of information are retrieved, they are used to help guide or condition the generative model to produce more accurate, contextually aware, or specific responses. This might involve using the retrieved text as additional context for the generation phase.\n\nRAG is particularly useful in scenarios where the model needs to provide factual information that it was not explicitly programmed with or trained on. By accessing and integrating external information at the time of query, RAG models can potentially provide more up-to-date and specific answers compared to standalone generative models.'
